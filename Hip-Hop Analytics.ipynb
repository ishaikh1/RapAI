# %% [markdown]
# # Hip-Hop Analytics
#
# This notebook analyzes trends in popular American Hip-Hop lyrics from 1990 to today. Time frames are broken up into periods of ten years or until currently, i.e.: 1990-1999, 2000-2009, 2010-Today. Each era will be analyzed individually before being presented together.
#
# For each era we will present:
#    - Artists used for analyzation
#    - Number of songs analyzed per artist
#    - Topic being analyzed
#    - Individual scores for topic per era
#    - Group score for topic per era
#    - Artist with highest scores for topic per era
#    - Artist with lowest scores for topic per era
#    - Possible offsets in data
#    - Trends and possible reasoning
#
# Topics analyzed are:
#    - Use of curse words
#    - Use of racial slurs
#    - Use of sexual slurs
#    - Most used non-filler words

# %%
#Imports for python functions beings run
from IPython.display import Image
from IPython.core.display import HTML 
from IPython.display import display_html
from IPython.display import display
from IPython.display import Math
from IPython.display import Latex
from IPython.display import HTML 

import matplotlib.pyplot as plt
import numpy as np
from numpy import arange,linspace

# %% [markdown]
# # 1990-1999
#
# Artists being analyzed are:
#    - Tupac Shakur (2Pac)
#        - 39 songs
#        - 35,331 lyrics
#    - Beastie Boys
#        - 32 songs
#        - 8,665 lyrics
#    - Coolio
#        - 17 songs
#        - 10,394 lyrics
#    - Dr. Dre
#        - 18 songs
#        - 11,652 lyrics
#    - Snoop Dogg
#        - 19 songs
#        - 8,843 lyrics
#    - A Tribe Called Quest
#        - 33 songs
#        - 20,879 lyrics
#    - Nas
#        - 26 songs
#        - 17,918 lyrics
#    - N.W.A
#        - 17 songs
#        - 9,358 lyrics
#    - Sir Mix-a-Lot
#        - 13 songs
#        - 9,840 lyrics
#    - The Notorious B.I.G.
#        - 44 songs
#        - 30,148 lyrics
#    - Will Smith
#        - 15 songs
#        - 7,321 lyrics
#    - Wu-Tang-Clan
#        - 14 songs
#        - 10,492 lyrics
#    - Totals
#        - 287 songs
#        - 180,742 lyrics

# %% [markdown]
# ## Use of curse words

# %%
swear_jar = {'fuck':0, 'shit':0, 'damn':0, 'hell':0, 'crap':0}

lyrics = open('1990-1999/AllSongs/all1990-1999.txt', 'r')

for line in lyrics:
    for word in line.split():
        if(word in swear_jar):
            swear_jar[word] +=1
        
x_values = np.arange(len(swear_jar.keys()))
num_swears = swear_jar.values()

plt.bar(x_values, num_swears, align='center', alpha=0.5)
plt.xticks(x_values, swear_jar.keys())
plt.title('CURSE WORD USAGE FROM: 1990-1999')
plt.ylabel("TIMES USED")
plt.xlabel("WORDS")
plt.show()

for i in swear_jar:
    print(i, ': ', swear_jar[i])
# Out:
# fuck :  317
# shit :  510
# damn :  60
# hell :  38
# crap :  5

# %% [markdown]
# ### Use of the word 'fuck'

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('fuck' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "FUCK": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  243
# Beastie Boys :  11
# Coolio :  38
# Dr. Dre :  184
# Snoop Dogg :  124
# A Tribe Called Quest :  7
# Nas :  46
# N.W.A :  206
# Sir Mix-a-Lot :  8
# The Notorious B.I.G. :  331
# Will Smith :  0
# Wu-Tang-Clan :  122

# %% [markdown]
# ### Use of the word 'shit'

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('shit' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "SHIT": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  133
# Beastie Boys :  13
# Coolio :  26
# Dr. Dre :  94
# Snoop Dogg :  55
# A Tribe Called Quest :  25
# Nas :  83
# N.W.A :  71
# Sir Mix-a-Lot :  7
# The Notorious B.I.G. :  157
# Will Smith :  1
# Wu-Tang-Clan :  53

# %% [markdown]
# ### Use of the word 'damn'

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('damn' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "DAMN": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  10
# Beastie Boys :  4
# Coolio :  13
# Dr. Dre :  10
# Snoop Dogg :  4
# A Tribe Called Quest :  14
# Nas :  5
# N.W.A :  4
# Sir Mix-a-Lot :  5
# The Notorious B.I.G. :  17
# Will Smith :  6
# Wu-Tang-Clan :  8

# %% [markdown]
# ### Use of the word 'hell'

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('hell' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "HELL": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  16
# Beastie Boys :  3
# Coolio :  2
# Dr. Dre :  6
# Snoop Dogg :  2
# A Tribe Called Quest :  6
# Nas :  5
# N.W.A :  2
# Sir Mix-a-Lot :  3
# The Notorious B.I.G. :  13
# Will Smith :  2
# Wu-Tang-Clan :  6

# %% [markdown]
# ### Use of the word 'crap'

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('crap' in word and word != 'craps'):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "CRAP": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  1
# Beastie Boys :  0
# Coolio :  1
# Dr. Dre :  4
# Snoop Dogg :  1
# A Tribe Called Quest :  3
# Nas :  0
# N.W.A :  0
# Sir Mix-a-Lot :  0
# The Notorious B.I.G. :  1
# Will Smith :  2
# Wu-Tang-Clan :  0

# %% [markdown]
# ## Use of most common racial slurs

# %%
artists = {'2Pac':0, 'Beastie Boys':0, 'Coolio':0, 'Dr. Dre':0, 'Snoop Dogg':0, 'A Tribe Called Quest':0, 'Nas':0, 'N.W.A':0, 'Sir Mix-a-Lot':0, 'The Notorious B.I.G.':0, 'Will Smith':0, 'Wu-Tang-Clan':0}

for i in artists:
    lyrics = open('1990-1999/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('nigga' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "N Word": 1990-1999')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 2Pac :  499
# Beastie Boys :  0
# Coolio :  56
# Dr. Dre :  143
# Snoop Dogg :  108
# A Tribe Called Quest :  23
# Nas :  182
# N.W.A :  206
# Sir Mix-a-Lot :  9
# The Notorious B.I.G. :  234
# Will Smith :  0
# Wu-Tang-Clan :  55

# %% [markdown]
# ## Use of sexual slurs

# %%
swear_jar = {'bitch':0, 'hoe':0,'gay':0, 'fag':0, 'slut':0}

lyrics = open('1990-1999/AllSongs/all1990-1999.txt', 'r')

for line in lyrics:
    for word in line.split():
        if(word in swear_jar):
            swear_jar[word] +=1
        
x_values = np.arange(len(swear_jar.keys()))
num_swears = swear_jar.values()

plt.bar(x_values, num_swears, align='center', alpha=0.5)
plt.xticks(x_values, swear_jar.keys())
plt.title('SEXUAL SLUR USAGE FROM: 1990-1999')
plt.ylabel("TIMES USED")
plt.xlabel("WORDS")
plt.show()

for i in swear_jar:
    print(i, ': ', swear_jar[i])
# Out:
# bitch :  286
# hoe :  4
# gay :  2
# fag :  0
# slut :  2

# %% [markdown]
# # 2000-2009
#
# Artists being analyzed are:
#    - 50 Cent
#        - 35 songs
#        - 18,749 lyrics
#    - Eminem
#        - 89 songs
#        - 50,167 lyrics
#    - Jay Z
#        - 31 songs
#        - 19,096 lyrics
#    - Kanye West
#        - 50 songs
#        - 22,514 lyrics
#    - Lil Wayne
#        - 21 songs
#        - 14,752 lyrics
#    - Outkast
#        - 40 songs
#        - 13,548
#    - Shaggy
#        - 7 songs
#        - 3,417 lyrics
#    - T.I.
#        - 18 songs
#        - 24,312
#    - T-Pain
#        - 19 songs
#        - 7,135

# %% [markdown]
# ## Use of curse words

# %%
swear_jar = {'fuck':0, 'shit':0, 'damn':0, 'hell':0, 'crap':0}

lyrics = open('2000-2009/AllSongs/all2000-2009.txt', 'r')

for line in lyrics:
    for word in line.split():
        if(word in swear_jar):
            swear_jar[word] +=1
        
x_values = np.arange(len(swear_jar.keys()))
num_swears = swear_jar.values()

plt.bar(x_values, num_swears, align='center', alpha=0.5)
plt.xticks(x_values, swear_jar.keys())
plt.title('CURSE WORD USAGE FROM: 2000-2009')
plt.ylabel("TIMES USED")
plt.xlabel("WORDS")
plt.show()

for i in swear_jar:
    print(i, ': ', swear_jar[i])
# Out:
# fuck :  298
# shit :  498
# damn :  59
# hell :  44
# crap :  4

# %% [markdown]
# ### Use of the word 'fuck'

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('fuck' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "FUCK": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  117
# Eminem :  364
# Jay Z :  76
# Kanye West :  33
# Lil Wayne :  66
# Outkast :  22
# Shaggy :  0
# T.I. :  38
# T-Pain :  10

# %% [markdown]
# ### Use of the word 'shit'

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('shit' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "SHIT": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  97
# Eminem :  234
# Jay Z :  72
# Kanye West :  67
# Lil Wayne :  37
# Outkast :  31
# Shaggy :  0
# T.I. :  106
# T-Pain :  16

# %% [markdown]
# ### Use of the word 'damn'

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('damn' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "DAMN": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  9
# Eminem :  29
# Jay Z :  15
# Kanye West :  7
# Lil Wayne :  9
# Outkast :  9
# Shaggy :  0
# T.I. :  14
# T-Pain :  14

# %% [markdown]
# ### Use of the word 'hell'

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('hell' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "HELL": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  12
# Eminem :  24
# Jay Z :  7
# Kanye West :  4
# Lil Wayne :  1
# Outkast :  7
# Shaggy :  1
# T.I. :  14
# T-Pain :  0

# %% [markdown]
# ### Use of the word 'crap'

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('crap' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "crap": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  0
# Eminem :  9
# Jay Z :  2
# Kanye West :  4
# Lil Wayne :  0
# Outkast :  0
# Shaggy :  0
# T.I. :  0
# T-Pain :  0

# %% [markdown]
# ## Use of most common racial slurs

# %%
artists = {'50 Cent':0, 'Eminem':0, 'Jay Z':0, 'Kanye West':0, 'Lil Wayne':0, 'Outkast':0, 'Shaggy':0, 'T.I.':0, 'T-Pain':0}

for i in artists:
    lyrics = open('2000-2009/AllSongs/all' + i + '.txt', 'r')

    for line in lyrics:
        for word in line.split():
            if('nigga' in word):
                artists[i] +=1

    x_values = np.arange(len(artists.keys()))
    num_swears = artists.values()

plt.barh(x_values, num_swears, align='center', alpha=0.5)
plt.yticks(x_values, artists.keys())
plt.title('USAGE OF "N Word": 2000-2009')
plt.xlabel("TIMES USED")
plt.show()

for i in artists:
    print(i, ': ', '' + str(artists[i]))
# Out:
# 50 Cent :  167
# Eminem :  11
# Jay Z :  111
# Kanye West :  53
# Lil Wayne :  31
# Outkast :  29
# Shaggy :  1
# T.I. :  156
# T-Pain :  11

# %% [markdown]
# ## Use of sexual slurs

# %%
swear_jar = {'bitch':0, 'hoe':0,'gay':0, 'fag':0, 'slut':0}

lyrics = open('2000-2009/AllSongs/all2000-2009.txt', 'r')

for line in lyrics:
    for word in line.split():
        if(word in swear_jar):
            swear_jar[word] +=1
        
x_values = np.arange(len(swear_jar.keys()))
num_swears = swear_jar.values()

plt.bar(x_values, num_swears, align='center', alpha=0.5)
plt.xticks(x_values, swear_jar.keys())
plt.title('SEXUAL SLUR USAGE FROM: 2000-2009')
plt.ylabel("TIMES USED")
plt.xlabel("WORDS")
plt.show()

for i in swear_jar:
    print(i, ': ', swear_jar[i])
# Out:
# bitch :  148
# hoe :  0
# gay :  5
# fag :  5
# slut :  11

# %% [markdown]
# # 2010-Current
#
# Artists being analyzed are:
#    - ASAP Rocky
#        - 11 songs
#        - 9,145 lyrics
#    - Big Shaq
#        - 1 song
#        - 438 lyrics
#    - Chance The Rapper
#        - 24 songs
#        - 13,060 lyrics
